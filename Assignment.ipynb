# %%
import pandas as pd
df = pd.read_excel("Exercise Data.xlsx")
df
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
# Month                                       25 non-null int64
# Contribution                                25 non-null int64
# Amount won by the bidder                    25 non-null int64
# Chit fund organizer commission              25 non-null int64
# Net amount recd by Bid winner               25 non-null int64
# Amount returned to everyone in the group    25 non-null int64
# dtypes: int64(6)
# memory usage: 1.2 KB

# %%
list(df)
# Out:
# ['Month',
#  'Contribution',
#  'Amount won by the bidder',
#  'Chit fund organizer commission',
#  'Net amount recd by Bid winner',
#  'Amount returned to everyone in the group']

# %%
a = df.shape[0]

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df.head()
# Out:
#    Month  Contribution  Amount_won_by_the_bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit_fund_organizer_commission  Net_amount_recd_by_Bid_winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount_returned_to_everyone_in_the_group
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400

# %%
list(df)
# Out:
# ['Month',
#  'Contribution',
#  'Amount_won_by_the_bidder',
#  'Chit_fund_organizer_commission',
#  'Net_amount_recd_by_Bid_winner',
#  'Amount_returned_to_everyone_in_the_group']

# %%
df['Annualized_Return_of_bid_winner_this_month']=df.Net_amount_recd_by_Bid_winner+sum(df.Amount_returned_to_everyone_in_the_group)

# %%
df['Annualized_benefit_of_bid_winner_this_month']= df.Annualized_Return_of_bid_winner_this_month - sum(df.Contribution)

# %%
total_contribution = sum(df.Contribution)

# %%
df['Annualized_percentage_return_of_bid_winner_this_month']=(df.Annualized_Return_of_bid_winner_this_month/total_contribution)
df.head()
# Out:
#    Month  Contribution  Amount_won_by_the_bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit_fund_organizer_commission  Net_amount_recd_by_Bid_winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount_returned_to_everyone_in_the_group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
# ...

# %%
df
# Out:
#     Month  Contribution  Amount_won_by_the_bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
#Annualized  Return of the person who bids in the last month ? 
print('Annualized  Return of the person who bids in the last month is  ---',df.Annualized_Return_of_bid_winner_this_month[24],'rupees.')
# Out:
# Annualized  Return of the person who bids in the last month is  --- 53700 rupees.

# %%
#Annualized Return of the person who bids in the first month ?
print('Annualized  Return of the person who bids in the first month is   ---',df.Annualized_Return_of_bid_winner_this_month[0],'rupees.')
# Out:
# Annualized  Return of the person who bids in the first month is   --- 43700 rupees.

# %%
list(df)
# Out:
# ['Month',
#  'Contribution',
#  'Amount_won_by_the_bidder',
#  'Chit_fund_organizer_commission',
#  'Net_amount_recd_by_Bid_winner',
#  'Amount_returned_to_everyone_in_the_group',
#  'Annualized_Return_of_bid_winner_this_month',
#  'Annualized_benefit_of_bid_winner_this_month',
#  'Annualized_percentage_return_of_bid_winner_this_month']

# %%
#Visualization of Annualized return
import matplotlib.pyplot as plt
plt.bar(Sol.Month, Sol.Annualized_Return_of_bid_winner_this_month)
plt.axhline(y=total_contribution, color='b', linestyle='--',label=total_contribution)
plt.text(15, total_contribution, total_contribution, fontsize=16, va='center', ha='center')
plt.title('Annualized_return_for_month_bid_winner')
plt.ylabel('Annualized_Return_of_bid_winner_this_month')
plt.xlabel('Month')

plt.show()

# %%
#R/Python script which calculates the annualized return of chit fund participant ?- Show the Return % for each month's bid winner.
Sol=df[['Month','Annualized_Return_of_bid_winner_this_month','Annualized_percentage_return_of_bid_winner_this_month']]
Sol
# Out:
#     Month  Annualized_Return_of_bid_winner_this_month  \
# 0       1                                       43700
# 1       2                                       45700
# 2       3                                       48700
# 3       4                                       51700
# 4       5                                       43700
# 5       6                                       45700
# 6       7                                       46700
# 7       8                                       47700
# 8       9                                       43700
# 9      10                                       45700
# 10     11                                       48700
# 11     12                                       51700
# 12     13                                       43700
# 13     14                                       45700
# 14     15                                       46700
# 15     16                                       46700
# ...
